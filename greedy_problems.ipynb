# %% [markdown]
# # Greedy Algorithems

# %%
def Assign_Cookies(student, cookie):
    student.sort()
    cookie.sort()
    i,j,n,m = 0,0,len(student),len(cookie)
    count = 0
    while i < n and j < m:
        if student[i] <= cookie[j]:
            count += 1
            i += 1
            j += 1
        else:
            j += 1
        
    return count

Assign_Cookies(student = [1, 4] , cookie = [1, 2, 3])
# Out:
# 1

# %%
# Class to represent an item with value and weight
class Item:
    def __init__(self, value, weight):
        self.value = value
        self.weight = weight

# Function to calculate the maximum value we can get with fractional knapsack
def fractionalKnapsack(W, arr, n):

    # Sort items based on the value/weight ratio in descending order
    arr.sort(key=lambda x: (x.value / x.weight), reverse=True)

    curWeight = 0  # Current weight of knapsack
    finalvalue = 0.0  # Final value we can achieve

    # Iterate through the sorted items
    for i in range(n):

        # If the current item can be fully added to the knapsack
        if curWeight + arr[i].weight <= W:
            curWeight += arr[i].weight
            finalvalue += arr[i].value  # Add the full value of the item
        else:
            # If the current item can't be fully added, take the fractional part
            remain = W - curWeight
            finalvalue += (arr[i].value / arr[i].weight) * remain
            break  # Break as we have filled the knapsack

    return finalvalue  # Return the maximum value that can be carried

# Main function
def main():
    # Input val
    n = 3
    weight = 50  # Capacity of knapsack
    arr = [Item(100, 20), Item(60, 10), Item(120, 30)]

    # Calculate the maximum value we can get with the fractional knapsack
    ans = fractionalKnapsack(weight, arr, n)

    # Output the result
    print(f"The maximum value is: {ans:.2f}")

# Call the main function
if __name__ == "__main__":
    main()

# %% [markdown]
# ## Fractional Knapsack Problem : Greedy Approach
#
# Input:
#  val = [60, 100, 120], wt = [10, 20, 30], capacity = 50
# Output:
#  240.000000

# %%
class Item:
    def __init__(self, value, weight):
        self.weight = weight
        self.value = value
        self.efficiency = self.value/self.weight

class Solution:
    def fractionalKnapsack(self, cap, wt, val):
        arr = []
        for i in range(len(wt)):
            arr.append(Item(val[i],wt[i]))
        arr.sort(key = lambda x : x.efficiency, reverse = True)
        weights = 0
        values = 0
        for i in arr:
            print(i.efficiency)
        for i in arr:
            if (weights + i.weight) < cap:
                weights += i.weight
                values += i.value
            else:
                values += ((cap - weights) / i.weight) * i.value
                break

        return values

val = [60, 100, 120]
wt = [10, 20, 30]
capacity = 50  

s = Solution()
s.fractionalKnapsack(capacity, wt, val)
# Out:
# 6.0
# 5.0
# 4.0
# 240.0

# %%
class Solution:
    def Minimum_Coins(self,coins, amount):
        coins_len = len(coins)
        amount_arr = [i for i in range(amount + 1)]
        dp = [[0] * (amount + 1) for i in range(coins_len)]
        # print(dp,n,m)
        for i in range(coins_len):
            for j in range(len(amount_arr)):
                rem = amount_arr[j] % coins[i]
                if rem == 0:
                    dp[i][j] = amount_arr[j] // coins[i]
                    continue
                if i - 1 > -1:
                    if dp[i-1][rem] != -1:
                        dp[i][j] = (amount_arr[j] // coins[i]) + dp[i-1][rem]
                        continue

                dp[i][j] = -1
        print(dp[coins_len-1][len(amount_arr)-1])
                        
                
                



    
s = Solution()
s.Minimum_Coins(coins = [1, 2, 5], amount = 11)
# Out:
# 3

# %%
# Solution class to implement tabulation approach
class Solution:
    # Function to find minimum coins
    def coinChange(self, coins, amount):
        # Creating dp array of size amount+1
        dp = [float('inf')] * (amount + 1)

        # Base case: dp[0] = 0
        dp[0] = 0

        for i in range(1, amount + 1):
            for coin in coins:
                if i-coin >= 0 and dp[i - coin] != float('inf'):
                    dp[i] = min(dp[i], dp[i-coin] + 1)

        return -1 if dp[amount] == float('inf') else dp[amount]

coins = [1, 2, 5]
amount = 11

obj = Solution()
print(obj.coinChange(coins, amount))
# Out:
# 3

# %%
class Solution:
    # Function to find minimum coins
    def changeReturn(self, bils):
        # Creating dp array of size amount+1
        d = {5:0,10:0,20:0}

        for i in bils:
            d[i] += 1

            if i == 10:
                if d[5] == 0:
                    return False
                d[5] -= 1
            elif i == 20:
                c = 15
                if d[5] == 0 or (d[10] == 0 and d[5] < 3) :
                    return False
                
                if d[10] == 0:
                    d[5] -= 3
                else:
                    d[10] -= 1
                    d[5] -= 1
        
        return True

if __name__ == "__main__":
    bills = [5, 5, 10, 10, 20]

    print("Queue of customers:", bills)

    stand = Solution()
    ans = stand.changeReturn(bills)

    if ans:
        print("It is possible to provide change for all customers.")
    else:
        print("It is not possible to provide change for all customers.")
# Out:
# Queue of customers: [5, 5, 10, 10, 20]
# It is not possible to provide change for all customers.

# %%
class Solution:

    # Function to check if the string is valid using greedy logic
    def checkValidString(self, s: str) -> bool:

        # Variable to store minimum number of open brackets possible
        min_open = 0

        # Variable to store maximum number of open brackets possible
        max_open = 0

        # Traverse each character in the string
        for char in s:

            # If current character is '('
            if char == '(':
                min_open += 1
                max_open += 1

            # If current character is ')'
            elif char == ')':
                min_open -= 1
                max_open -= 1

            # If current character is '*', it can be '(', ')' or ''
            else:
                 # If '*' acts as ')'
                min_open -= 1    
                # If '*' acts as '('
                max_open += 1      

            # If max_open goes below 0, we have too many unmatched ')'
            if max_open < 0:
                return False

            # min_open should not be negative
            if min_open < 0:
                min_open = 0

        # At the end, all opens must be matched for valid string
        return min_open == 0


# Driver code
if __name__ == "__main__":
    s = input("Enter the string: ")
    sol = Solution()
    if sol.checkValidString(s):
        print("Valid parenthesis string")
    else:
        print("Invalid parenthesis string")
# Out:
# Invalid parenthesis string

# %% [markdown]
# # Jump Game 2

# %% [markdown]
# Input: nums = [2, 3, 1, 1, 4]
#
# Output: 2
# Explanation: Jump from index 0 → 1 → 4.

# %%
def jumpGame2(nums):
    jumps = 0
    i = 0
    while i < len(nums) - 1:
        jumps += 1
        c = nums[i]
        print(c)
        max_num = -1
        if i + c >= len(nums) - 1:
            return jumps
        while c > 0:
            c -= 1
            if nums[i+1] > c and nums[i+1] > max_num:
                next_idx = i + 1
                max_num = nums[i+1]
            i += 1
        i = next_idx
    return jumps

nums = [2, 3, 4,5,6,7,8,9]
jumpGame2(nums)
# Out:
# 2
# 4
# 8
# 3

# %%
class Solution:
     #Function to compute the minimum number of jumps to reach the last index
    def jump(self, nums):
        # Initialize jump counter and bounds
        jumps = 0
        current_end = 0
        farthest = 0

        # Traverse through the array except the last element
        for i in range(len(nums) - 1):
            # Update the farthest index that can be reached from current index
            farthest = max(farthest, i + nums[i])

            # If we have reached the end of current range
            if i == current_end:
                # Increment jump counter
                jumps += 1

                # Move the range to the farthest position we can reach
                current_end = farthest

        # Return the minimum number of jumps
        return jumps
# Driver Code
if __name__ == "__main__":
    sol = Solution()
    nums = [2, 3, 1, 1, 4]
    print("Minimum jumps required:", sol.jump(nums))

# %% [markdown]
# Input:  N=6,
# arr[] = {9:00, 9:45, 9:55, 11:00, 15:00, 18:00}
# dep[] = {9:20, 12:00, 11:30, 11:50, 19:00, 20:00}

# %%
def train(arr,dep):
    schedule = [(dep[i], arr[i], i+1) for i in range(len(arr))]
    schedule.sort()
    heap_end = []
    import heapq
    platform = 0
    heapq.heappush(heap_end,2401)

    for i in schedule:
        end = heap_end[0]
        if i[1] > end:
            heapq.heappop(heap_end)
        else:
            platform += 1
        heapq.heappush(heap_end,i[0])
    
    return platform
        
arr = ["9:00", "9:45", "9:55", "11:00", "15:00", "18:00"]
dep = ["9:20", "12:00", "11:30", "11:50", "19:00", "20:00"]
arr = ["09:00", "10:15", "11:00","09:30" ]
dep = ["09:45", "11:30","12:00","10:00"]
arr = ["10:00", "10:10", "10:20"]
dep = ["10:30", "10:15", "10:25"]
arr = ["10:00", "10:05", "10:06"]
dep = ["10:07", "10:08", "10:09"]
arr = ["10:00", "10:50", "10:40"]
dep = ["11:00", "11:10", "10:45"]
dep1 = []
for i in dep:
    j = i.replace(":","")
    dep1.append(int(j))

arr1 = []
for i in arr:
    j = i.replace(":","")
    arr1.append(int(j))

print(dep1)
train(arr1,dep1)
# Out:
# [1100, 1110, 1045]
# 2

# %%
def helper(i,arr,memo):
    if i == 0:
        memo[i] = arr[i]
        return arr[i]
    

def ShortedtJobFirst(arr):
    arr.sort()
    n = len(arr)
    memo = [0] * len(arr)
    sum1 = 0
    for i in range(0,len(arr)-1):
        sum1 += arr[i]
        memo[i+1] = sum1
    return sum(memo) / n

ShortedtJobFirst([1,2,3,4,7])
# Out:
# 4.0

# %%
class Job:
    def __init__(self, num, dead, profit):
        self.num = num
        self.dead = dead
        self.profit = profit

def JobSequencingProblem(jobs):
    jobs.sort(key=lambda x: (x.dead, -x.profit))
    total_profit = 0
    prev_dead = 0
    for job in jobs:
        if job.dead > prev_dead:
            total_profit += job.profit
            prev_dead = job.dead
    return total_profit

    

jobs = [Job(1, 4, 20), Job(2, 1, 10), Job(3, 2, 40), Job(4, 2, 30)]

JobSequencingProblem(jobs)
# Out:
# 70

# %%
l = [3,1,3,4]
l[1:] = [2,3,4]
l
# Out:
# [3, 2, 3, 4]

# %%
ratings = [1, 3, 6, 8, 9, 5, 3]

def countCandy(ratings):
    candy = [1] * len(ratings)
    for i in range(1,len(ratings)):
        if ratings[i] > ratings[i-1]:
            candy[i] = candy[i-1] + 1

    for i in range(len(ratings)-2,-1,-1):
        if ratings[i] > ratings[i+1] and candy[i] <= candy[i+1]:
            candy[i] = candy[i+1] + 1   

    return sum(candy)

countCandy(ratings)
# Out:
# 18

# %%
class Node:
    def __init__(self, val, left = None, right = None):
        self.left = left
        self.right = right
        self.val = val

def preOrder(root):
    if not root:
        return

    st = [root]
    result = []
    while st:
        node = st.pop(0)
        result.append(node.val)
        if node.left:
            st.append(node.left)
        if node.right:
            st.append(node.right)
        
    return result

if __name__ == "__main__":

    # Creating a sample binary tree
    root = Node(1)
    root.left = Node(2)
    root.right = Node(3)
    root.left.left = Node(4)
    root.left.right = Node(5)

    # Getting preorder traversal
    # sol = Solution()
    result = preOrder(root)

    # Displaying the preorder traversal result
    print("Preorder Traversal: ", end="")
    # Output each value in the
    # preorder traversal result
    for val in result:
        print(val, end=" ")
    print()
# Out:
# Preorder Traversal: 1 2 3 4 5

# %%
class Node:
    def __init__(self, val, left = None, right = None):
        self.left = left
        self.right = right
        self.val = val

def inOrder(root):
    if not root:
        return

    st = []
    result = []
    curr = root
    while st or curr:
        while curr:
            st.append(curr)
            curr = curr.left

        curr = st.pop()
        result.append(curr.val)
        curr = curr.right
        
    return result

if __name__ == "__main__":

    # Creating a sample binary tree
    root = Node(1)
    root.left = Node(2)
    root.right = Node(3)
    root.left.left = Node(4)
    root.left.right = Node(5)

    # Getting preorder traversal
    # sol = Solution()
    result = inOrder(root)

    # Displaying the preorder traversal result
    print("Preorder Traversal: ", end="")
    # Output each value in the
    # preorder traversal result
    for val in result:
        print(val, end=" ")
    print()
# Out:
# Preorder Traversal: 4 2 5 1 3

# %%
class Node:
    def __init__(self, val, left = None, right = None):
        self.left = left
        self.right = right
        self.val = val

def postOrder(root):
    if not root:
        return

    last_visited = None
    st = []
    result = []
    curr = root
    while st or curr:
        if curr:
            st.append(curr)
            curr = curr.left
        else:
            peek = st[-1]
            if peek.right and last_visited != peek.right:
                curr = peek.right
            else:
                result.append(peek.val)
                last_visited = st.pop(-1)

    return result

if __name__ == "__main__":

    # Creating a sample binary tree
    root = Node(1)
    root.left = Node(2)
    root.right = Node(3)
    root.left.left = Node(4)
    root.left.right = Node(5)

    # Getting preorder traversal
    # sol = Solution()
    result = postOrder(root)

    # Displaying the preorder traversal result
    print("Preorder Traversal: ", end="")
    # Output each value in the
    # preorder traversal result
    for val in result:
        print(val, end=" ")
    print()
# Out:
# Preorder Traversal: 4 5 2 3 1

# %%
# Node structure for the binary tree
class Node:
    # Constructor to initialize the node with a value
    def __init__(self, val):
        self.val = val
        self.left = None
        self.right = None

# Solution class containing the traversal function
class Solution:
    # Function to get the Preorder,
    # Inorder and Postorder traversal
    # Of Binary Tree in One traversal
    def preInPostTraversal(self, root):
        # Lists to store traversals
        pre, ino, post = [], [], []

        # If the tree is empty, return empty traversals
        if root is None:
            return []

        # Stack to maintain nodes and their traversal state
        st = [(root, 1)]

        while st:
            node, state = st.pop()
            print(state)
            # this is part of pre
            if state == 1:
                # Store the node's val in the preorder traversal
                pre.append(node.val)
                # Move to state 2 (inorder) for this node
                st.append((node, 2))

                # Push left child onto the stack for processing
                if node.left:
                    st.append((node.left, 1))

            # this is a part of in
            elif state == 2:
                # Store the node's val in the inorder traversal
                ino.append(node.val)
                # Move to state 3 (postorder) for this node
                st.append((node, 3))

                # Push right child onto the stack for processing
                if node.right:
                    st.append((node.right, 1))

            # this is part of post
            else:
                # Store the node's val in the postorder traversal
                post.append(node.val)

        # Returning the traversals
        return [pre, ino, post]

# Main function
if __name__ == "__main__":
    # Creating a sample binary tree
    root = Node(1)
    root.left = Node(2)
    root.right = Node(3)
    root.left.left = Node(4)
    root.left.right = Node(5)

    # Create object of Solution class
    sol = Solution()

    # Getting the traversals
    traversals = sol.preInPostTraversal(root)

    # Extracting and printing the traversals
    pre = traversals[0]
    ino = traversals[1]
    post = traversals[2]

    print("Preorder traversal:", *pre)
    print("Inorder traversal:", *ino)
    print("Postorder traversal:", *post)
# Out:
# 1
# 1
# 1
# 2
# 3
# 2
# 1
# 2
# 3
# 3
# 2
# 1
# 2
# 3
# 3
# Preorder traversal: 1 2 4 5 3
# Inorder traversal: 4 2 5 1 3
# Postorder traversal: 4 5 2 3 1

# %%
def depth(root):
    if not root:
        return 0
    q = [root]
    level = 0

    while q:
        s = len(q)

        for i in range(s):
            f = q.pop(0) 
            if f.left:
                q.append(f.left)
            if f.right:
                q.append(f.right)
        
        level += 1
    
    return level

depth(root)
# Out:
# 3

# %%
def balanced_tree(root):
    if not root:
        return True
    
    if root.left:
        l = depth(root.left)

    if root.right:
        r = depth(root.right)
    
    if abs(l - r) > 1:
        return False
    
    return True
root = Node(1)
root.left = Node(2)
root.right = Node(3)
root.left.left = Node(4)
root.left.right = Node(5)
root.left.right.right = Node(6)
root.left.right.right.right = Node(7)
balanced_tree(root)
# Out:
# False

# %%
def height(root):
    if not root:
        return 0

    leftHeight = height(root.left)
    if leftHeight == -1:
        return -1

    reightheight = height(root.right)
    if reightheight:
        return -1

    if abs(leftHeight - reightheight) > 1:
        return -1
    return max(leftHeight,reightheight) + 1 
    
def balanced(root):
    return height(root) != -1

balanced(root)
# Out:
# False

# %%
class TreeNode:
    def __init__(self, val, left = None, right = None):
        self.right = right
        self.left = left
        self.val = val

# %%
class Solution:
    def __init__(self):
        self.maximum_sum = 0

    def binary_tree_path_sum(self,root):
        if not root:
            return 0
        
        leftSum = self.binary_tree_path_sum(root.left)
        rightSum = self.binary_tree_path_sum(root.right)

        self.maximum_sum = max(leftSum + rightSum + root.val, self.maximum_sum, rightSum + root.val, leftSum + root.val)

        return max(root.val + leftSum, root.val + rightSum, root.val)

    def max_path_sum(self, root):
        self.binary_tree_path_sum(root)
        return self.maximum_sum

root = TreeNode(-10)
root.left = TreeNode(9)
root.right = TreeNode(20)
root.right.left = TreeNode(15)
root.right.right = TreeNode(7)

sol = Solution()
print("Maximum Path Sum:",sol.max_path_sum(root))
# Out:
# Maximum Path Sum: 42

# %%
# Node class for the binary tree
class Node:
    def __init__(self, val):
        self.val = val  # val stored in the node
        self.left = None  # Pointer to the left child
        self.right = None  # Pointer to the right child

class Solution:
    # Function to check if two binary trees are identical
    def isIdentical(self, node1, node2):
        # Case 1: If both nodes are NULL, they are identical
        if node1 is None and node2 is None:
            return True

        # Case 2: If only one of the nodes is NULL, they are not identical
        if node1 is None or node2 is None:
            return False

        # Check if the current nodes have the same val value
        # and recursively check their left and right subtrees
        return (node1.val == node2.val) and \
               self.isIdentical(node1.left, node2.left) and \
               self.isIdentical(node1.right, node2.right)

# Driver code
if __name__ == "__main__":
    # Creating the first binary tree (Node1)
    root1 = Node(1)
    root1.left = Node(2)
    root1.right = Node(3)
    root1.left.left = Node(4)

    # Creating the second binary tree (Node2)
    root2 = Node(1)
    root2.left = Node(2)
    root2.right = Node(3)
    root2.left.left = Node(4)

    # Creating an instance of the Solution class
    solution = Solution()

    # Check if the two binary trees are identical and output the result
    if solution.isIdentical(root1, root2):
        print("The binary trees are identical.")
    else:
        print("The binary trees are not identical.")
# Out:
# The binary trees are not identical.

# %%
from collections import deque

# Class to represent a binary tree node
class TreeNode:
    def __init__(self, x):
        self.val = x          # Value of the node
        self.left = None      # Pointer to left child
        self.right = None     # Pointer to right child

class Solution:
    # Function to perform zigzag (spiral) level order traversal
    def zigzagLevelOrder(self, root):
        # List to store the final zigzag traversal result
        result = []

        # If tree is empty, return empty list
        if not root:
            return result

        # Queue for BFS traversal
        q = deque([root])

        # Boolean flag to control traversal direction
        leftToRight = True

        # Loop until all levels are processed
        while q:
            # Get the number of nodes at the current level
            size = len(q)

            # Temporary list to store current level's values
            level = [0] * size

            # Process each node in the current level
            for i in range(size):
                # Get the front node from queue
                node = q.popleft()

                # Determine index where this value should be stored
                index = i if leftToRight else size - 1 - i
                level[index] = node.val

                # Add left child to queue if it exists
                if node.left:
                    q.append(node.left)
                # Add right child to queue if it exists
                if node.right:
                    q.append(node.right)

            # Flip direction for the next level
            leftToRight = not leftToRight

            # Add current level to result
            result.append(level)

        # Return zigzag traversal result
        return result

# Driver code
if __name__ == "__main__":
    # Create binary tree:
    #        1
    #      /   \
    #     2     3
    #    / \     \
    #   4   5     6
    root = TreeNode(1)
    root.left = TreeNode(2)
    root.right = TreeNode(3)
    root.left.left = TreeNode(4)
    root.left.right = TreeNode(5)
    root.right.right = TreeNode(6)

    # Create solution object
    sol = Solution()

    # Get zigzag traversal
    ans = sol.zigzagLevelOrder(root)

    # Print result
    print(ans)
# Out:
# [[1]]
# 1
# [3, 2]
# 2
# [4, 5, 6]
# 3
# []
# [[1], [3, 2], [4, 5, 6], []]

# %%
# Definition for a binary tree node.
class Node:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

class Solution:
    def __init__(self):
        self.res = []
    def isLeaf(self, root: TreeNode):
        if not root.left and not root.right:
            return True
        return False
    def leafTraversal(self, root: TreeNode):
        if not root:
            return
        if self.isLeaf(root):
            self.res.append(root.val)
        self.leafTraversal(root.left)
        self.leafTraversal(root.right)
    def leftTraversal(self, root: TreeNode):
        curr = root.left
        while curr:
            if not self.isLeaf(curr):
                # If the current node is not a leaf,
                # add its value to the result
                self.res.append(curr.val)
            # Move to the left child if it exists,
            # otherwise move to the right child
            if curr.left:
                curr = curr.left
            else:
                curr = curr.right
    def rightTraversal(self, root: TreeNode):
        curr = root.right
        temp = []
        while curr:
            if not self.isLeaf(curr):
                # If the current node is not a leaf,
                # add its value to a temporary vector
                temp.append(curr.val)
            # Move to the right child if it exists,
            # otherwise move to the left child
            if curr.right:
                curr = curr.right
            else:
                curr = curr.left
        # Reverse and add the values from
        # the temporary vector to the result
        for i in range(len(temp) - 1, -1, -1):
            self.res.append(temp[i])
    def boundryTraversat(self, root: TreeNode):
        """
        Main function to perform the
        boundary traversal of the binary tree
        """
        if not root:
            return self.res

        if not self.isLeaf(root):
            self.res.append(root.val)


        self.leftTraversal(root)
        self.leafTraversal(root)
        self.rightTraversal(root)

        return self.res


root = Node(1)
root.left = Node(2)
root.left.left = Node(4)
root.left.right = Node(10)
root.left.left.right = Node(5)
root.left.left.right.right = Node(6)
root.right = Node(3)
root.right.right = Node(10)
root.right.left = Node(9)

solution = Solution()

# Get the boundary traversal
result = solution.boundryTraversat(root)

# Print the result
print("Boundary Traversal:", end=" ")
result
# Out:
# Boundary Traversal:
# [1, 2, 4, 5, 6, 10, 9, 10, 3]

# %%
# Definition for a binary tree node.
class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

class Solution:
    def __init__(self):
        self.d = {}

    def topViewTraversal(self, root, x) -> int:
        if not root:
            return
        if x not in self.d:
            self.d[x] = root.val
        
        self.topViewTraversal(root.left, x-1)
        self.topViewTraversal(root.right, x+1)

    def topView(self, root):
        self.topViewTraversal(root, 0)
        res = []
        for i in sorted(self.d.keys()):
            res.append(self.d[i])
        return res


s = Solution()
s.topView(root)
# Out:
# [4, 2, 1, 3, 10]

# %%
# Definition for a binary tree node.
class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

class Solution:
    def __init__(self):
        self.d = {}

    def bottomViewTraversal(self, root, x) -> int:
        if not root:
            return
        
        self.d[x] = root.val
        
        self.bottomViewTraversal(root.left, x-1)
        self.bottomViewTraversal(root.right, x+1)

    def bottomView(self, root):
        self.bottomViewTraversal(root, 0)
        res = []
        for i in sorted(self.d.keys()):
            res.append(self.d[i])
        return res


root = Node(1)
root.left = Node(2)
root.left.left = Node(4)
root.left.right = Node(10)
root.left.left.right = Node(5)
root.left.left.right.right = Node(6)
root.right = Node(3)
root.right.right = Node(10)
root.right.left = Node(9)
s = Solution()
s.bottomView(root)
# Out:
# [4, 5, 9, 3, 10]

# %%
# Definition for a binary tree node.
class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

class Solution:
    def __init__(self):
        self.d = {}

    def rightViewTraversal(self, root, x, y) -> int:
        if not root:
            return
        
        if y not in self.d or x > self.d[y][1]:
            self.d[y] = (root.val, x)
        
        self.rightViewTraversal(root.right, x+1, y+1)
        self.rightViewTraversal(root.left, x-1, y+1)

    def rightView(self, root):
        self.rightViewTraversal(root, 0, 0)
        res = []
        for i in sorted(self.d.keys()):
            res.append(self.d[i][0])
        return res


root = Node(1)
root.left = Node(2)
root.left.left = Node(4)
root.left.right = Node(10)
root.left.left.right = Node(5)
root.left.left.right.right = Node(6)
root.right = Node(3)
root.right.right = Node(10)
root.right.left = Node(9)
s = Solution()
s.rightView(root)
# Out:
# [1, 3, 10, 5, 6]

# %%
# Definition for a binary tree node.
class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

class Solution:
    def Symetric(self, root: TreeNode) -> int:
        res = self.helper(root, root)
        return res
    
    def helper(self, root1, root2): 
        if not root1 and not root2:
            return 0
        if not root1 or not root2:
            return -1
        
        if root1.val != root2.val:
            return -1
        
        return (self.helper(root1.left, root2.right) and
                self.helper(root1.right, root2.left))

root = Node(1)
root.left = Node(2)
root.right = Node(2)
root.left.left = Node(4)
root.right.right = Node(4)
root.left.right = Node(5)
root.right.left = Node(5)

s= Solution()

s.Symetric(root)
# Out:
# 0

# %%
class Node:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

def helper(root, val, l):
    if not root:
        return
    if root.val == val:
        l = l + str(root.val)
        return l
    helper(root.left, val, l + str(root.val))
    helper(root.right, val, l + str(root.val))

def print_root_to_node(root, val):
    if not root:
        return
    l = ""
    return helper(root, val, l)

root = Node(1)
root.left = Node(2)
root.right = Node(7)
root.left.left = Node(4)
root.right.right = Node(6)
root.left.right = Node(5)
root.right.left = Node(3)

# s= Solution()

p = print_root_to_node(root, 5)
p
# Out:
# 1 2 5

# %%
# Definition for a binary tree node.
class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

class Solution:
    def path_finder(self,root, val, l):
        if not root:
            return
        if root.val == val:
            return l + str(root.val)
        path = self.path_finder(root.left, val, l + str(root.val))
        if path:
            return path
        path = self.path_finder(root.right, val, l + str(root.val))
        if path:
            return path
        return path

    def LCA(self, root: TreeNode, val1, val2):
        if not root:
            return
        l1 = ""
        l2 = ""
        path1 = self.path_finder(root, val1, l1)
        path2 = self.path_finder(root, val2, l2)
        print(path1)
        print(path2)
        n1 = len(path1)- 1
        n2 = len(path2) - 1
        n_max = max(n1,n2)

        while n1 >= 0 and n2 >= 0:
            if path1[n1] == path2[n2]:
                return path1[n1]
            elif n1 > n2:
                n1 -= 1
            elif n2 > n1:
                n2 -= 1
            else:
                n1 -= 1
                n2 -= 1
        
        return "path not found"
    
root = Node(1)
root.left = Node(2)
root.right = Node(7)
root.left.left = Node(4)
root.right.right = Node(6)
root.left.right = Node(5)
root.right.left = Node(3)

s= Solution()

s.LCA(root, 7, 3)
# Out:
# 17
# 173
# '7'

# %%
# Definition for a binary tree node.
class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

class Solution:
    def LCA(self, root: TreeNode, p, q):
        if not root or root == p or root == q:
            return root
        left = self.LCA(root.left, p,q)
        right = self.LCA(root.right,p,q)

        if left == None:
            return right
        elif right == None:
            return left
        else:
            return root
    
root = Node(1)
root.left = Node(2)
root.right = Node(7)
p = root.left.left = Node(4)
root.right.right = Node(6)
q = root.left.right = Node(5)
root.right.left = Node(3)

s= Solution()

s.LCA(root, p, q).val
# Out:
# 2

# %%
class Solution:
    def width_of_binary_tree(self, root):
        if not root:
            return 0
        max_width = 0
        
        q = Deque()
        q = append((root,0))

        while q:
            size = len(q)
            min_index = q[0][1]

            for i in range(size):
                node, idx = q.popleft()
                curr_idx = idx - min_index

                if i == 0:
                    first = curr_idx
                
                if i == size - 1:
                    last = curr_idx

                if node.left:
                    q.append((node.left, 
                              2 * curr_index + 1))
                
                if node.right:
                    q.append((node.right, 
                              2 * curr_index + 2))
            
            max_width = max(last - first + 1, max_width)

        return max_width

# %%
class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

class Solution:
    def ChildSum(self, root: TreeNode):
        if not root:
            return
        
        child = 0
        if root.left:
            child += root.left.val
        if root.right:
            child += root.right.val
        
        if child >= root.val:
            root.val = child
        else:
            if root.left:
                root.left.val = root.val
            elif root.right:
                root.right.val = root.val

        self.ChildSum(root.left)
        self.ChildSum(root.right)
        
        tot = 0
        if root.left:
            tot += root.left.val
        if root.right:
            tot += root.right.val
            
        if root.left or root.right:
            root.val = tot

    def printTree(self, root):
        if not root:
            return
        print(root.val)
        self.printTree(root.left)
        self.printTree(root.right)
     
root = TreeNode(3)
root.left = TreeNode(5)
root.right = TreeNode(1)
root.left.left = TreeNode(6)
root.left.right = TreeNode(2)
root.right.left = TreeNode(0)
root.right.right = TreeNode(8)
root.left.right.left = TreeNode(7)
root.left.right.right = TreeNode(4)
s= Solution()
s.ChildSum(root)

s.printTree(root)
# Out:
# 25
# 17
# 6
# 11
# 7
# 4
# 8
# 0
# 8

# %%
# Definition for a binary tree node.
class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

class Solution:
    def __init__(self):
        self.res = []
    def KDistance(self, root: TreeNode, t, k):
        if not root:
            return
        if root.left:
            print("At left", root.left.val)
            if root.left.val == t:
                print("target at left")
                self.FindNodes(root.left, t, k)
                self.FindNodes(root, t, k-1)
            else:
                self.KDistance(root.left,t, k) 
        if root.right:
            print("At right",root.right.val)
            if root.right.val == t:
                print("Targeta at right")
                self.FindNodes(root.right, t, k)
                self.FindNodes(root, t, k-1)
            else:
                self.KDistance(root.right,t, k) 
        return self.res
    def FindNodes(self, root, t, k):
        if not root or k < 0:
            return
        print(root.val,k)
        if k == 0:
            self.res.append(root.val)
            return   
        self.FindNodes(root.left, t, k - 1)
        self.FindNodes(root.right, t, k - 1)

s = Solution()
root = TreeNode(3)
root.left = TreeNode(5)
root.right = TreeNode(1)
root.left.left = TreeNode(6)
root.left.right = TreeNode(2)
root.right.left = TreeNode(0)
root.right.right = TreeNode(8)
root.left.right.left = TreeNode(7)
root.left.right.right = TreeNode(4)

s.KDistance(root,2,2)
# Out:
# At left 5
# At left 6
# At right 2
# Targeta at right
# 2 2
# 7 1
# 4 1
# 5 1
# 6 0
# 2 0
# At right 1
# At left 0
# At right 8
# [6, 2]

# %%
from collections import deque

class Solution:
    def __init__(self):
        self.parentMap = {}
    def findT(self, root, t):
        if not root:
            return
        if t == root.val:
            return root
        self.findT(root.left, t)
        self.findT(root.right, t)
    def FindKDistance(self,root, t, k):
        if not root:
            return
        
        self.map_parent(root)
        q = deque()
        q.append(root)
        while q:
            s = len(q)
            for i in range(s):
                curr = q.popleft()
                
                if curr.val == t:
                    target = curr
                    break
                
                if curr.left:
                    q.append(curr.left)  
                
                if curr.right:
                    q.append(curr.right)
        # print(target.val)
        # print(self.parentMap)
        return self.findNodes(target, t, k)
    
    def map_parent(self, root):
        if not root:
            return

        if root.left:
            self.parentMap[root.left] = root
        if root.right:
            self.parentMap[root.right] = root
        
        self.map_parent(root.left)
        self.map_parent(root.right)
        
    def findNodes(self, root, t, k):
        q = deque()
        visited = set()
        visited.add(root)
        q.append(root)
        current_lvl = 0
        
        while q and current_lvl < k:
            size = len(q)
            
            for i in range(size):
                curr = q.popleft()
                if curr.left and (curr.left not in visited):
                    visited.add(curr.left)
                    q.append(curr.left)
                if curr.right and (curr.right not in visited):
                    visited.add(curr.right)
                    q.append(curr.right)
                if self.parentMap[curr] and (self.parentMap[curr] not in visited):
                    visited.add(self.parentMap[curr])
                    q.append(self.parentMap[curr])
            current_lvl += 1
        
        return q
    
    
s = Solution()
root = TreeNode(3)
root.left = TreeNode(5)
root.right = TreeNode(1)
root.left.left = TreeNode(6)
root.left.right = TreeNode(2)
root.right.left = TreeNode(0)
root.right.right = TreeNode(8)
root.left.right.left = TreeNode(7)
root.left.right.right = TreeNode(4)

q = s.FindKDistance(root,2,1)    
for i in q:
    print(i.val)
# Out:
# 7
# 4
# 5

# %%
from collections import deque

class Solution:
    def __init__(self):
        self.parentMap = {}
    def findT(self, root, t):
        if not root:
            return
        if t == root.val:
            return root
        self.findT(root.left, t)
        self.findT(root.right, t)
    def FindKDistance(self,root, t):
        if not root:
            return
        
        self.map_parent(root)
        q = deque()
        q.append(root)
        while q:
            s = len(q)
            for i in range(s):
                curr = q.popleft()
                
                if curr.val == t:
                    target = curr
                    break
                
                if curr.left:
                    q.append(curr.left)  
                
                if curr.right:
                    q.append(curr.right)
        # print(target.val)
        # print(self.parentMap)
        return self.findNodes(target, t)
    
    def map_parent(self, root):
        if not root:
            return

        if root.left:
            self.parentMap[root.left] = root
        if root.right:
            self.parentMap[root.right] = root
        
        self.map_parent(root.left)
        self.map_parent(root.right)
        
    def findNodes(self, root, t):
        q = deque()
        visited = set()
        visited.add(root)
        q.append(root)
        current_lvl = 0
        
        while q:
            size = len(q)      
            for i in range(size):
                curr = q.popleft()
                if curr.left and (curr.left not in visited):
                    visited.add(curr.left)
                    q.append(curr.left)
                if curr.right and (curr.right not in visited):
                    visited.add(curr.right)
                    q.append(curr.right)
                if curr in self.parentMap and (self.parentMap[curr] not in visited):
                    visited.add(self.parentMap[curr])
                    q.append(self.parentMap[curr])
            current_lvl += 1
        
        return current_lvl
    
    
if __name__ == "__main__":
    root = TreeNode(1)
    root.left = TreeNode(2)
    root.right = TreeNode(3)
    root.left.left = TreeNode(4)
    root.right.left = TreeNode(5)
    root.right.right = TreeNode(6)
    root.left.left.right = TreeNode(7)

    target = 1
    sol = Solution()
    print("Minimum time to burn the tree:", sol.FindKDistance(root, target))
# Out:
# Minimum time to burn the tree: 4

# %%
class Solution:
    def builtTree(self, preorder, inorder):
        in_map = {val: idx for idx, val in enumerate(inorder)}
        def built(preStart, preEnd, inStart, inEnd):
            if preEnd < preStart or inEnd < inStart:
                return None
            
            idx_val = preorder[preStart]
            root = TreeNode(idx_val)
            idx = in_map[idx_val]
            numsLeft = idx - inStart
            
            root.left = built(preStart + 1, preStart + numsLeft, inStart, idx- 1)
            root.right = built(preStart + numsLeft + 1, preEnd, idx + 1, inEnd)

            return root
        
        return built(0, len(preorder) - 1, 0, len(inorder) - 1)
    
    def printInorder(self,root):
        if not root:
            return
        self.printInorder(root.left)
        print(root.val, end=" ")
        self.printInorder(root.right)
        

if __name__ == "__main__":
    inorder = [9, 3, 15, 20, 7]
    preorder = [3, 9, 20, 15, 7]

    sol = Solution()
    root = sol.builtTree(preorder, inorder)

    print("Inorder of Unique Binary Tree Created:")
    sol.printInorder(root)
    print()
# Out:
# Inorder of Unique Binary Tree Created:
# 9 3 15 20 7

# %%
# Class to represent a binary tree node
class TreeNode:
    def __init__(self, x):
        self.val = x
        self.left = None
        self.right = None

class Solution:
    # Function to count nodes in a complete binary tree
    def countNodes(self, root):
        # If tree is empty, return 0
        if not root:
            return 0
        # Get height from leftmost path
        lh = self.findHeightLeft(root)
        # Get height from rightmost path
        rh = self.findHeightRight(root)
        # If heights match, it's a perfect binary tree
        if lh == rh:
            return (1 << lh) - 1
        # Otherwise, recursively count left and right subtrees
        return 1 + self.countNodes(root.left) + self.countNodes(root.right)

    # Helper to find height from leftmost path
    def findHeightLeft(self, node):
        height = 0
        while node:
            height += 1
            node = node.left
        return height

    # Helper to find height from rightmost path
    def findHeightRight(self, node):
        height = 0
        while node:
            height += 1
            node = node.right
        return height

# Driver code
if __name__ == "__main__":
    # Create binary tree
    root = TreeNode(1)
    root.left = TreeNode(2)
    root.right = TreeNode(3)
    root.left.left = TreeNode(4)
    root.left.right = TreeNode(5)
    root.right.left = TreeNode(6)

    # Create solution object
    sol = Solution()

    # Count total nodes
    totalNodes = sol.countNodes(root)

    # Output result
    print("Total number of nodes in the Complete Binary Tree:", totalNodes)
# Out:
# Total number of nodes in the Complete Binary Tree: 6

# %%
def countNodes(root):
    lh = lengthLh(root)
    rh = lengthrh(root)
    
    if lh == rh:
        return (1 << lh) - 1
    return 1 + countNodes(root.left) + countNodes(root.right)

# %%
def postOrderAndInorder(preOrder,inOrder):
    preOrder = preOrder[::-1]
    inMap = {val:i for i,val in enumerate(inOrder)}
    def build(preStart,preEnd,inStart,inEnd):
        if preEnd < preStart or inEnd < inStart:
            return
        val = preOrder[preStart]
        idx = inMap[val]
        root = TreeNode(val)
        remaining = idx - inStart + preStart
        
        root.left = build(remaining, preEnd, inStart, idx)
        root.right = build(preStart + 1, preEnd, idx + 1, inEnd)
        
        return root
    return build(0, len(preOrder) - 1, 0, len(inOrder) - 1)


inOrder = [40, 20, 50, 10, 60, 30]
postOrder = [40, 50, 20, 60, 30, 10]
postOrderAndInorder(postOrder,inOrder)
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# Cell In[12], line 19
#      17 inOrder = [40, 20, 50, 10, 60, 30]
#      18 postOrder = [40, 50, 20, 60, 30, 10]
# ---> 19 postOrderAndInorder(postOrder,inOrder)
#
# Cell In[12], line 16, in postOrderAndInorder(preOrder, inOrder)
#      13     root.right = build(preStart + 1, preEnd, idx + 1, inEnd)
#      15     return root
# ---> 16 return build(0, len(preOrder) - 1, 0, len(inOrder) - 1)
#
# Cell In[12], line 12, in postOrderAndInorder.<locals>.build(preStart, preEnd, inStart, inEnd)
#       9 root = TreeNode(val)
#      10 remaining = idx - inStart + preStart
# ---> 12 root.left = build(remaining, preEnd, inStart, idx)
#      13 root.right = build(preStart + 1, preEnd, idx + 1, inEnd)
#      15 return root
#
# Cell In[12], line 13, in postOrderAndInorder.<locals>.build(preStart, preEnd, inStart, inEnd)
# ...

# %%
# Definition for a binary tree node.
class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

# %%
def inOrder(root):
    inList = []
    curr = root
    
    while curr:
        if curr.left == None:
            inList.append(curr.val)
            curr = curr.right
        else:
            prev = curr.left
            while prev.right and prev.right != curr:
                prev = prev.right
            
            if prev.right == None:
                prev.right = curr
                curr = curr.left
            else:
                prev.right = None
                inList.append(curr.val)
                curr = curr.right
                
        
    return inList
root = TreeNode(1)
root.left = TreeNode(2)
root.right = TreeNode(3)
root.left.left = TreeNode(4)
root.left.right = TreeNode(5)
root.left.right.right = TreeNode(6)
inOrder(root)
# Out:
# [4, 2, 5, 6, 1, 3]

# %%
# TreeNode class
class TreeNode:
    def __init__(self, x):
        self.val = x
        self.left = None
        self.right = None


class Solution:
    def morrisPreorder(self, root):
        result = []
        cur = root

        while cur:
            if cur.left is None:
                # ✅ SAME in both (visit if no left)
                result.append(cur.val)
                cur = cur.right
            else:
                prev = cur.left

                # Find inorder predecessor
                while prev.right and prev.right != cur:
                    prev = prev.right

                if prev.right is None:
                    # 🔴 DIFFERENCE (PREORDER)
                    result.append(cur.val)   # visit BEFORE going left

                    prev.right = cur        # create thread
                    cur = cur.left
                else:
                    prev.right = None       # remove thread
                    cur = cur.right

        return result

# %%
class Solution:
    def flatten(self, root):
        curr = root
        while curr:
            if curr.left:
                pre = curr.left
                while pre.right:
                    pre = pre.right
                pre.right = curr.right
                curr.right = curr.left
                curr.left = None
            curr = curr.right

# %%
from collections import deque

# %%
def deserialize(list_tree):
    if len(list_tree) <= 0 or list_tree[0] == "#":
        return
    q = deque()
    list_tree = [0] + list_tree
    root = TreeNode(list_tree[1])
    q.append((root,1))
    n = len(list_tree)
    while q:
        node,idx = q.popleft()
        if idx*2 < n and list_tree[idx*2] != "#":
            node.left = TreeNode(list_tree[idx*2])
            q.append((node.left,idx*2))
        if idx*2 + 1 < n and list_tree[idx*2 + 1] != "#":
            node.right = TreeNode(list_tree[idx*2+1])
            q.append((node.right,idx*2+1))  
    return root

def preOrder(root):
    if not root:
        return
    print(root.val)
    preOrder(root.left)
    preOrder(root.right)

l = [1,2,3,'#','#',4,5,'#','#','#','#']

r = deserialize(l)
preOrder(r)
# Out:
# 1
# 2
# 3
# 4
# 5
