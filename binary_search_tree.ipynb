# %%
from typing import Optional

# Definition for a binary tree node.
class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

class Solution:
    def searchBST(self, root: TreeNode, target):
        if not root:
            return None
        while root != None and root.val != target:
            if root.val > target:
                root = root.left
            else:
                root = root.right
                
        return root


if __name__ == "__main__":
    root = TreeNode(4)
    root.left = TreeNode(2)
    root.right = TreeNode(7)
    root.left.left = TreeNode(1)
    root.left.right = TreeNode(3)

    obj = Solution()
    result = obj.searchBST(root, 0)
    if result:
        print("Found")
    else:
        print("NotFound")
# Out:
# NotFound

# %%
# Definition for a binary tree node.
class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

class Solution:
    def FindMinMax(self, root: TreeNode):
        if not root:
            return None
        
        r = root
        while root.left:
            root = root.left
        min_val = root.val
        
        while r.right:
            r = r.right
        
        max_val = r.val
        
        return [min_val,max_val]


if __name__ == "__main__":
    root = TreeNode(4)
    root.left = TreeNode(2)
    root.right = TreeNode(7)
    root.left.left = TreeNode(1)
    root.left.right = TreeNode(3)

    obj = Solution()
    result = obj.FindMinMax(root)
    print(result)
# Out:
# [1, 7]

# %%
from typing import Optional

# Definition for a binary tree node.
class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

class Solution:
    def findFloor(self, root: TreeNode, target):
        if not root:
            return None
        floor_val = None
        while root != None:
            if root.val > target:
                # upper_val = root.val
                root = root.left
            else:
                floor_val = root.val
                root = root.right
                
        return floor_val,upper_val


if __name__ == "__main__":
    root = TreeNode(4)
    root.left = TreeNode(2)
    root.right = TreeNode(7)
    root.left.left = TreeNode(1)
    root.left.right = TreeNode(3)

    obj = Solution()
    result = obj.findFloor(root, 5)
    if result:
        print("Found",result)
    else:
        print("NotFound")
# Out:
# Found 4

# %%
from typing import Optional

# Definition for a binary tree node.
class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

class Solution:
    def TreeAfetrInsertion(self,root,insert_val):
        temp = root
        self.insertNode(temp,insert_val)
        return root
        
    def insertNode(self, root: TreeNode, insert_val):
        if not root:
            root = TreeNode(insert_val)
            return root
        if root.val > insert_val:
            root.left = self.insertNode(root.left,insert_val)
        else:
            root.right = self.insertNode(root.right,insert_val)    
        return root

def levelOrder(root):
    if not root:
        return 0
    q = [root]
    while q:
        s = len(q)
        for i in range(s):
            f = q.pop(0) 
            print(f.val,end=" ")
            if f.left:
                q.append(f.left)
            if f.right:
                q.append(f.right)
    

if __name__ == "__main__":
    root = TreeNode(4)
    root.left = TreeNode(2)
    root.right = TreeNode(7)
    root.left.left = TreeNode(1)
    root.left.right = TreeNode(3)
    root.left.right = TreeNode(6)

    obj = Solution()
    result = obj.TreeAfetrInsertion(root, 8)
    levelOrder(result)
# Out:
# 4 2 7 1 6 8

# %%
# Definition for a binary tree node.
class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

class Solution:
    
    def DeletionInBST(self, root: TreeNode, key):
        if not root:
            return None

        if key < root.val:
            print("left")
            root.left = self.DeletionInBST(root.left, key)

        elif key > root.val:
            print("right")
            root.right = self.DeletionInBST(root.right, key)

        else:
            # Case 1: No left child
            if not root.left:
                return root.right
            
            # Case 2: No right child
            if not root.right:
                return root.left
            
            # Case 3: Two children
            # Find inorder successor (smallest in right subtree)
            temp = root.right
            while temp.left:
                temp = temp.left

            # Replace root value
            root.val = temp.val

            # Delete the inorder successor
            root.right = self.DeletionInBST(root.right, temp.val)
        
        return root
def levelOrder(root):
    if not root:
        return 0
    q = [root]
    while q:
        s = len(q)
        for i in range(s):
            f = q.pop(0) 
            print(f.val,end=" ")
            if f.left:
                q.append(f.left)
            if f.right:
                q.append(f.right)

if __name__ == "__main__":
    root = TreeNode(4)
    root.left = TreeNode(2)
    root.right = TreeNode(7)
    root.left.left = TreeNode(1)
    root.left.right = TreeNode(3)

    obj = Solution()
    result = obj.DeletionInBST(root, 3)
    levelOrder(result)
# Out:
# left
# right
# 4 2 7 1

# %%
# Definition for a binary tree node.
class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

class Solution:
    def helper(self,root,key):
        temp= root
        self.DeletionInBST(temp,key)
        return root
    def DeletionInBST(self, root: TreeNode, key):
        if not root:
            return None

        if key < root.val:
            print("left")
            root.left = self.DeletionInBST(root.left, key)

        elif key > root.val:
            print("right")
            root.right = self.DeletionInBST(root.right, key)

        else:
            if not root.left:
                return root.right
            if not root.right:
                return root.left
            root.val = root.right.val
            tempLeft = root.right.left
            root.right = root.right.right
            temp = root.left
            
            while temp.right:
                temp = temp.right
            
            temp.right = tempLeft
            
        return root
def levelOrder(root):
    if not root:
        return 0
    q = [root]
    while q:
        s = len(q)
        for i in range(s):
            f = q.pop(0) 
            print(f.val,end=" ")
            if f.left:
                q.append(f.left)
            if f.right:
                q.append(f.right)\
            
def preOrder(root):
    if not root:
        return
    print(root.val,end= " ")
    preOrder(root.left)
    preOrder(root.right)
                


if __name__ == "__main__":
    root = TreeNode(4)
    root.left = TreeNode(2)
    root.right = TreeNode(7)
    root.left.left = TreeNode(1)
    root.left.right = TreeNode(3)

    obj = Solution()
    result = obj.DeletionInBST(root, 4)
    levelOrder(result)
    preOrder(result)
# Out:
# 7 2 1 3 7 2 1 3

# %%
# Definition for a binary tree node.
class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

class Solution:
    def buildBST(self, root: TreeNode,val):
        if not root:
            node = TreeNode(val)
            return node
        if val > root.val:
            root.right = self.buildBST(root.right, val)
        else:
            root.left = self.buildBST(root.left, val)
        
        return root
    def BSTFromInorder(self,inOrder):
        root = None
        for i in inOrder:
            root = self.buildBST(root,i)
            print(root.val)
        return root


if __name__ == "__main__":
    root = TreeNode(4)
    root.left = TreeNode(2)
    root.right = TreeNode(7)
    root.left.left = TreeNode(1)
    root.left.right = TreeNode(3)

    obj = Solution()
    result = obj.BSTFromInorder([8,5,1,7,10,12])
    preOrder(result)
# Out:
# 8
# 8
# 8
# 8
# 8
# 8
# 8 5 1 7 10 12

# %%
# Definition for a binary tree node.
class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

class Solution:
    def buildBST(self, pre, l, r):
        if r < l:
            return None
        
        root = TreeNode(pre[l])
        
        if l == r:
            return root
        
        i = l+1
        while i <= r and pre[i] <= root.val:
            i += 1
        
        root.left = self.buildBST(pre,l+1, i - 1)            
        root.right = self.buildBST(pre,i, r)
        
        return root
    
    def BSTFromInorder(self,preOrder):
        return self.buildBST(preOrder, 0, len(preOrder) - 1)


if __name__ == "__main__":
    root = TreeNode(4)
    root.left = TreeNode(2)
    root.right = TreeNode(7)
    root.left.left = TreeNode(1)
    root.left.right = TreeNode(3)

    obj = Solution()
    result = obj.BSTFromInorder([8,5,1,7,10,12])
    preOrder(result)
# Out:
# 8 5 1 7 10 12

# %%
class Node:
    def __init__(self, x):
        self.data = x
        self.left = None
        self.right = None
        
        
def construct_util(pre, low, high):
    if low > high:
        return None

    # Create the root node with the first
    # element in the current range
    root = Node(pre[low])

    if low == high:
        return root

    # Find the first element greater 
    # than root to divide the array
    i = low + 1
    while i <= high and pre[i] <= root.data:
        i += 1

    # Recursively construct left and right subtrees
    root.left = construct_util(pre, low + 1, i - 1)
    root.right = construct_util(pre, i, high)

    return root

# Constructs the BST from the preorder traversal
def construct(pre):
    return construct_util(pre, 0, len(pre) - 1)

# Utility function to print inorder traversal of the BST
def print_inorder(root):
    if root is None:
        return
    print_inorder(root.left)
    print(root.data, end=" ")
    print_inorder(root.right)

# Driver code
if __name__ == "__main__":
    pre = [10, 5, 1, 7, 40, 50]
    root = construct(pre)
    print_inorder(root)
# Out:
# 1 5 7 10 40 50

# %%
# Definition for a binary tree node.
class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

class Solution:
    def LCAinBST(self, root: TreeNode, p, q):
        if not root:
            return None
        if p > root.val and q > root.val:
            return self.LCAinBST(root.right, p,q)
        elif p < root.val and q < root.val:
            return self.LCAinBST(root.left, p, q)
        else:
            return root


if __name__ == "__main__":
    root = TreeNode(4)
    root.left = TreeNode(2)
    root.right = TreeNode(7)
    root.left.left = TreeNode(1)
    root.left.right = TreeNode(3)

    obj = Solution()
    result = obj.LCAinBST(root, 2,7)
    print(result)
# Out:
# 4

# %%
from typing import Optional

# Definition for a binary tree node.
class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

class Solution:
    def InOrderSuccessor(self, root: TreeNode, target):
        if not root:
            return None
        successor = None
        upper_val = None
        while root != None:
            if root.val <= target:
                root = root.right
            else:
                successor = root.val
                root = root.left            
        return successor


if __name__ == "__main__":
    root = TreeNode(5)
    root.left = TreeNode(3)
    root.right = TreeNode(6)
    root.left.left = TreeNode(2)
    root.left.right = TreeNode(4)
    root.right.right = TreeNode(7)

    obj = Solution()
    result = obj.InOrderSuccessor(root, 6)
    if result:
        print("Found",result)
    else:
        print("NotFound")
# Out:
# Found 7

# %%
# Global pointers
first = None
middle = None
last = None
prev = None


# Recursive Function for inorder traversal
# to find out the two swapped nodes
def correctBSTUtil(root):
    global first, middle, last, prev
    if root is None:
        return

    # Recur for the left subtree
    correctBSTUtil(root.left)

    if prev and root.val < prev.val:

        # first violation
        if first is None:
            first = prev
            middle = root

        # second violation
        else:
            last = root

    # Mark this node as previous
    prev = root

    # Recur for the right subtree
    correctBSTUtil(root.right)


# Function to fix the given BST
def correctBST(root):
    global first, middle, last, prev
    first = middle = last = prev = None

    correctBSTUtil(root)
    if first and last:
        swap(first, last)
    elif first and middle:
        swap(first, middle)

def swap(a, b):
    temp = a.val
    a.val = b.val
    b.val = temp

#Driver Code Starts
def levelOrder(root):
    if not root:
        return 0
    q = [root]
    while q:
        s = len(q)
        for i in range(s):
            f = q.pop(0) 
            print(f.val,end=" ")
            if f.left:
                q.append(f.left)
            if f.right:
                q.append(f.right)

if __name__ == "__main__":
    
    # Constructing the tree with swapped nodes
    #       6
    #     /  \
    #    10   2
    #   / \  / \
    #  1  3 7  12
 

    root = TreeNode(6)
    root.left = TreeNode(10)
    root.right = TreeNode(2)
    root.left.left = TreeNode(1)
    root.left.right = TreeNode(3)
    root.right.left = TreeNode(7)
    root.right.right = TreeNode(12)

    correctBST(root)
    levelOrder(root)

#Driver Code Ends
# Out:
# 6 2 10 1 3 7 12

# %%
import sys


# Node structure
class Node:
    def __init__(self, val):
        self.data = val
        self.left = None
        self.right = None

#Driver Code Ends

# Custom data type to keep track of Minimum, Maximum value,
# and Size of the largest BST
class BSTInfo:
    def __init__(self, mn, mx, sz):
        self.mini = mn
        self.maxi = mx
        self.mxSz = sz


# Recursive Function to find maximum size
def largestBSTBT(root):
    if not root:
        return BSTInfo(sys.maxsize, -sys.maxsize, 0)

    left = largestBSTBT(root.left)
    right = largestBSTBT(root.right)

    # Check if the current subtree is a BST
    if left.maxi < root.data and right.mini > root.data:
        return BSTInfo(min(left.mini, root.data),
                       max(right.maxi, root.data),
                       root.data + left.mxSz + right.mxSz)

    return BSTInfo(-sys.maxsize, sys.maxsize, max(left.mxSz, right.mxSz))


# Function to return the size of the largest BST
def largestBst(root):
    return largestBSTBT(root).mxSz

#Driver Code Starts

if __name__ == "__main__":
    
    # Constructed binary tree 
    #         5
    #       /   \
    #      2     4
    #     / \
    #    1   3
    root = Node(1)
    root.left = Node(4)
    root.right = Node(3)
    root.left.left = Node(2)
    root.left.right = Node(4)
    root.right.left = Node(2)
    root.right.right = Node(5)
    root.right.right.left = Node(4)
    root.right.right.right = Node(6)

    print(largestBst(root))
#Driver Code Ends
# Out:
# 20
